# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев
# для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
from pprint import pprint
import json

# %%
url = 'https://api.github.com'
user = 'erik-mv'
token = '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'

r = requests.get(f'{url}/users/{user}/repos')
pprint(r.json())
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/branches{/branch}',
#   'clone_url': 'https://github.com/erik-mv/Advanced-cpp-MADE.git',
#   'collaborators_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/erik-mv/Advanced-cpp-MADE/contents/{+path}',
# ...

# %%
with open('data.json', 'w') as f:
    json.dump(r.json(), f)

# %%
for i in r.json():
    print(i['name'])
# Out:
# Advanced-cpp-MADE
# Advanced-python-MADE
# Algorithms-and-data-structures-MADE
# Applied-reinforcement-learning
# Basic-machine-learning
# Basic_Algebra_for_ML
# Basic_Calculus_for_ML
# Conversational-AI-and-dialog-systems
# Game-theory-MADE
# GEO-services-MADE
# High-performance_computing_made2021
# MADE-robotics
# MADE_Bas_BigData
# ML-on-graphs
# NLP_MADE
# Parsing
# pytorch-lifestream
# Streamlit_test
# tabular-dl-num-embeddings

# %% [markdown]
# 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.
# Если нет желания заморачиваться с поиском, возьмите API вконтакте (https://vk.com/dev/first_guide). Сделайте запрос, чтобы получить список всех сообществ на которые вы подписаны.

# %%
api_key = 'jTB3mRdODk69sSrdQmo9jEMpFVtRzPOfOck2VvF0'
url = 'https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/latest_photos'

response = requests.get(f'{url}?api_key={api_key}')

pprint(response.json())
# Out:
# {'latest_photos': [{'camera': {'full_name': 'Front Hazard Avoidance Camera',
#                                'id': 20,
#                                'name': 'FHAZ',
#                                'rover_id': 5},
#                     'earth_date': '2023-02-14',
#                     'id': 1100595,
#                     'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03742/opgs/edr/fcam/FLB_729689488EDR_F1000084FHAZ00337M_.JPG',
#                     'rover': {'id': 5,
#                               'landing_date': '2012-08-06',
#                               'launch_date': '2011-11-26',
#                               'name': 'Curiosity',
#                               'status': 'active'},
#                     'sol': 3742},
#                    {'camera': {'full_name': 'Front Hazard Avoidance Camera',
#                                'id': 20,
#                                'name': 'FHAZ',
#                                'rover_id': 5},
# ...

# %%
params = {
    'earth_date': '2023-01-14',
    'name': 'FHAZ',
    'api_key': 'jTB3mRdODk69sSrdQmo9jEMpFVtRzPOfOck2VvF0'
}

url = 'https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos'

response = requests.get(url=url, params=params)

print(response.status_code)
pprint(response.json())
# Out:
# 200
# {'photos': [{'camera': {'full_name': 'Mast Camera',
#                         'id': 22,
#                         'name': 'MAST',
#                         'rover_id': 5},
#              'earth_date': '2023-01-14',
#              'id': 1084885,
#              'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03711/mcam/3711MR1033890001800788C00_DXXX.jpg',
#              'rover': {'id': 5,
#                        'landing_date': '2012-08-06',
#                        'launch_date': '2011-11-26',
#                        'name': 'Curiosity',
#                        'status': 'active'},
#              'sol': 3711},
#             {'camera': {'full_name': 'Mast Camera',
#                         'id': 22,
#                         'name': 'MAST',
#                         'rover_id': 5},
#              'earth_date': '2023-01-14',
#              'id': 1084886,
#              'img_src': 'https://mars.nasa.gov/msl-raw-images/msss/03711/mcam/3711ML1033900051504385I01_DXXX.jpg',
# ...
